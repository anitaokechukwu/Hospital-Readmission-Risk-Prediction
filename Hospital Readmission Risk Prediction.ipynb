# %% [markdown]
# ### Import libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Load dataset

# %%
df = pd.read_csv("hospital_readmission_risk_dataset_2026_v1_18000rows (1).csv")

# %% [markdown]
#  ### Data Understanding

# %% [raw]
# # Display the first 5 rows

# %%
df.head()
# Out:
#    Age  Gender Insurance_Type  Socioeconomic_Risk_Score  \
# 0   71    Male       Medicare                         9
# 1   34  Female        Private                         8
# 2   80    Male       Medicare                         2
# 3   40  Female        Private                         7
# 4   43    Male       Medicaid                         5
#
#    Previous_Admissions_6M  Previous_Readmissions_1Y  \
# 0                       2                         0
# 1                       4                         0
# 2                       1                         3
# 3                       2                         0
# 4                       2                         1
#
#    Time_Since_Last_Discharge  Length_of_Stay Admission_Type  \
# 0                         96              15         Urgent
# 1                         58              12         Urgent
# 2                         25              11         Urgent
# 3                         42               2       Elective
# ...

# %% [markdown]
# ### Check dataset shape

# %%
df.shape
# Out:
# (18000, 25)

# %% [markdown]
# ### View column names

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Insurance_Type', 'Socioeconomic_Risk_Score',
#        'Previous_Admissions_6M', 'Previous_Readmissions_1Y',
#        'Time_Since_Last_Discharge', 'Length_of_Stay', 'Admission_Type',
#        'Primary_Diagnosis_Group', 'Comorbidity_Index', 'Chronic_Disease_Count',
#        'ICU_Stay_Flag', 'Severity_Score', 'HbA1c_Level', 'Creatinine_Level',
#        'Hemoglobin_Level', 'Average_Systolic_BP', 'Number_of_Medications',
#        'Medication_Change_Count', 'High_Risk_Medication_Flag',
#        'Followup_Appointment_Scheduled', 'Discharge_Disposition',
#        'Medication_Adherence_Score', 'Readmitted_Within_30_Days'],
#       dtype='object')

# %% [markdown]
# ### Check data types

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             18000 non-null  int64
#  1   Gender                          18000 non-null  object
#  2   Insurance_Type                  18000 non-null  object
#  3   Socioeconomic_Risk_Score        18000 non-null  int64
#  4   Previous_Admissions_6M          18000 non-null  int64
#  5   Previous_Readmissions_1Y        18000 non-null  int64
#  6   Time_Since_Last_Discharge       18000 non-null  int64
#  7   Length_of_Stay                  18000 non-null  int64
#  8   Admission_Type                  18000 non-null  object
#  9   Primary_Diagnosis_Group         18000 non-null  object
#  10  Comorbidity_Index               18000 non-null  int64
#  11  Chronic_Disease_Count           18000 non-null  int64
# ...

# %% [markdown]
# ### Summary statistics

# %%
df.describe()
# Out:
#                 Age  Socioeconomic_Risk_Score  Previous_Admissions_6M  \
# count  18000.000000              18000.000000            18000.000000
# mean      54.504889                  5.006889                1.503944
# std       20.206770                  2.582783                1.225543
# min       20.000000                  1.000000                0.000000
# 25%       37.000000                  3.000000                1.000000
# 50%       54.000000                  5.000000                1.000000
# 75%       72.000000                  7.000000                2.000000
# max       89.000000                  9.000000                8.000000
#
#        Previous_Readmissions_1Y  Time_Since_Last_Discharge  Length_of_Stay  \
# count              18000.000000               18000.000000    18000.000000
# mean                   0.999667                  90.245889       10.049444
# std                    1.004518                  51.882074        5.455903
# ...

# %% [markdown]
# ### Data Cleaning

# %% [raw]
# # Check for missing values

# %%
df.isnull().sum()
# Out:
# Age                               0
# Gender                            0
# Insurance_Type                    0
# Socioeconomic_Risk_Score          0
# Previous_Admissions_6M            0
# Previous_Readmissions_1Y          0
# Time_Since_Last_Discharge         0
# Length_of_Stay                    0
# Admission_Type                    0
# Primary_Diagnosis_Group           0
# Comorbidity_Index                 0
# Chronic_Disease_Count             0
# ICU_Stay_Flag                     0
# Severity_Score                    0
# HbA1c_Level                       0
# Creatinine_Level                  0
# Hemoglobin_Level                  0
# Average_Systolic_BP               0
# Number_of_Medications             0
# Medication_Change_Count           0
# High_Risk_Medication_Flag         0
# Followup_Appointment_Scheduled    0
# Discharge_Disposition             0
# Medication_Adherence_Score        0
# Readmitted_Within_30_Days         0
# dtype: int64

# %% [markdown]
# ### Exploratory Data Analysis (EDA)

# %% [raw]
# Import Visualization Libraries

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Plot style
plt.style.use("ggplot")

# %% [markdown]
# ### Check Dataset Shape

# %%
print(f"Rows: {df.shape[0]}")
print(f"Columns: {df.shape[1]}")
# Out:
# Rows: 18000
# Columns: 25

# %% [markdown]
# ### Display Column Names

# %%
df.columns
# Out:
# Index(['Age', 'Gender', 'Insurance_Type', 'Socioeconomic_Risk_Score',
#        'Previous_Admissions_6M', 'Previous_Readmissions_1Y',
#        'Time_Since_Last_Discharge', 'Length_of_Stay', 'Admission_Type',
#        'Primary_Diagnosis_Group', 'Comorbidity_Index', 'Chronic_Disease_Count',
#        'ICU_Stay_Flag', 'Severity_Score', 'HbA1c_Level', 'Creatinine_Level',
#        'Hemoglobin_Level', 'Average_Systolic_BP', 'Number_of_Medications',
#        'Medication_Change_Count', 'High_Risk_Medication_Flag',
#        'Followup_Appointment_Scheduled', 'Discharge_Disposition',
#        'Medication_Adherence_Score', 'Readmitted_Within_30_Days'],
#       dtype='object')

# %% [markdown]
# ### Dataset Information

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18000 entries, 0 to 17999
# Data columns (total 25 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Age                             18000 non-null  int64
#  1   Gender                          18000 non-null  object
#  2   Insurance_Type                  18000 non-null  object
#  3   Socioeconomic_Risk_Score        18000 non-null  int64
#  4   Previous_Admissions_6M          18000 non-null  int64
#  5   Previous_Readmissions_1Y        18000 non-null  int64
#  6   Time_Since_Last_Discharge       18000 non-null  int64
#  7   Length_of_Stay                  18000 non-null  int64
#  8   Admission_Type                  18000 non-null  object
#  9   Primary_Diagnosis_Group         18000 non-null  object
#  10  Comorbidity_Index               18000 non-null  int64
#  11  Chronic_Disease_Count           18000 non-null  int64
# ...

# %% [markdown]
# ### Summary Statistics

# %%
df.describe().T
# Out:
#                                   count        mean        std     min  \
# Age                             18000.0   54.504889  20.206770   20.00
# Socioeconomic_Risk_Score        18000.0    5.006889   2.582783    1.00
# Previous_Admissions_6M          18000.0    1.503944   1.225543    0.00
# Previous_Readmissions_1Y        18000.0    0.999667   1.004518    0.00
# Time_Since_Last_Discharge       18000.0   90.245889  51.882074    1.00
# Length_of_Stay                  18000.0   10.049444   5.455903    1.00
# Comorbidity_Index               18000.0    2.475556   1.703104    0.00
# Chronic_Disease_Count           18000.0    1.991222   1.413951    0.00
# ICU_Stay_Flag                   18000.0    0.197778   0.398335    0.00
# Severity_Score                  18000.0    5.005500   2.576422    1.00
# HbA1c_Level                     18000.0    7.001696   1.491568    1.10
# Creatinine_Level                18000.0    1.198866   0.400166   -0.42
# ...

# %% [markdown]
# ### Check Missing Values

# %%
df.isnull().sum()
# Out:
# Age                               0
# Gender                            0
# Insurance_Type                    0
# Socioeconomic_Risk_Score          0
# Previous_Admissions_6M            0
# Previous_Readmissions_1Y          0
# Time_Since_Last_Discharge         0
# Length_of_Stay                    0
# Admission_Type                    0
# Primary_Diagnosis_Group           0
# Comorbidity_Index                 0
# Chronic_Disease_Count             0
# ICU_Stay_Flag                     0
# Severity_Score                    0
# HbA1c_Level                       0
# Creatinine_Level                  0
# Hemoglobin_Level                  0
# Average_Systolic_BP               0
# Number_of_Medications             0
# Medication_Change_Count           0
# High_Risk_Medication_Flag         0
# Followup_Appointment_Scheduled    0
# Discharge_Disposition             0
# Medication_Adherence_Score        0
# Readmitted_Within_30_Days         0
# dtype: int64

# %% [markdown]
# ### Check Duplicate Records

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [raw]
# If duplicates exist

# %%
df = df.drop_duplicates()

# %% [markdown]
# ### Examine the Target Variable

# %%
df['Readmitted_Within_30_Days'].value_counts()
# Out:
# Readmitted_Within_30_Days
# 1    13349
# 0     4651
# Name: count, dtype: int64

# %% [markdown]
# ### Also check percentages:

# %%
df['Readmitted_Within_30_Days'].value_counts(normalize=True) * 100
# Out:
# Readmitted_Within_30_Days
# 1    74.161111
# 0    25.838889
# Name: proportion, dtype: float64

# %% [markdown]
# ### Visualize the Target Variable

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x='Readmitted_Within_30_Days',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='Set2',
    legend=False
)

plt.title("Hospital Readmission Distribution")
plt.xlabel("Readmitted Within 30 Days")
plt.ylabel("Number of Patients")

plt.show()

# %% [raw]
# Insight to write
#
# The distribution of hospital readmissions shows
# the proportion of patients who were readmitted within 30 days
# compared to those who were not. Assessing class balance
# is important because highly imbalanced data may require
# specialized modeling techniques.

# %% [markdown]
# ### Numerical Feature Distributions

# %%
numerical_cols = df.select_dtypes(include=['int64','float64']).columns

df[numerical_cols].hist(
    figsize=(18,15),
    bins=30
)

plt.tight_layout()
plt.show()

# %% [raw]
# Insight
#
# Write observations such as:
#
# Age distribution
# Length of stay
# Laboratory measurements
# Medication adherence
# Severity scores

# %% [markdown]
# ### Boxplots for Outlier Detection

# %%
import math

# Select numerical columns
numerical_cols = df.select_dtypes(include=['int64', 'float64']).columns

# Define the number of columns in the subplot grid
n_cols = 4

# Calculate the required number of rows
n_rows = math.ceil(len(numerical_cols) / n_cols)

# Create the figure
plt.figure(figsize=(20, 5 * n_rows))

# Create boxplots
for i, col in enumerate(numerical_cols, 1):
    plt.subplot(n_rows, n_cols, i)
    sns.boxplot(y=df[col], color='skyblue')
    plt.title(col, fontsize=10)

plt.tight_layout()
plt.show()

# %% [raw]
# Insight: The boxplots reveal that several numerical variables
# contain outliers, particularly in measures such as Length of Stay,
# Previous Admissions, and Severity Score. These extreme values
# may represent patients with unusually complex medical
# conditions rather than data entry errors. Therefore,
# the outliers will be investigated further but not
# removed automatically, as they may carry important
# clinical information for predicting hospital readmission

# %%
len(numerical_cols)
# Out:
# 20

# %% [markdown]
# ### Correlation Heatmap

# %%
plt.figure(figsize=(14,10))

sns.heatmap(
    df[numerical_cols].corr(),
    annot=True,
    cmap='coolwarm',
    fmt=".2f"
)

plt.title("Correlation Heatmap")

plt.show()

# %% [raw]
# Insight
#
# Identify:
#
# Highly correlated variables
# Weak correlations
# Potential multicollinearity

# %% [markdown]
# ### Age Distribution

# %%
plt.figure(figsize=(8,5))

sns.histplot(
    df['Age'],
    bins=30,
    kde=True,
    color='steelblue'
)

plt.title("Age Distribution")

plt.show()

# %% [raw]
# Insight
#
# Discuss:
#
# Most common age group
# Younger vs older patients
# Whether the distribution appears normal or skewed

# %% [markdown]
# ### Gender Distribution

# %%
plt.figure(figsize=(6,4))

sns.countplot(
    x='Gender',
    hue='Gender',
    data=df,
    palette='pastel',
    legend=False
)

plt.title("Gender Distribution")
plt.xlabel("Gender")
plt.ylabel("Number of Patients")

plt.show()

# %% [raw]
# Insight
#
# Compare the proportion of male and female patients.

# %% [markdown]
# ### Admission Type

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    y='Admission_Type',
    hue='Admission_Type',
    data=df,
    order=df['Admission_Type'].value_counts().index,
    palette='viridis',
    legend=False
)

plt.title("Admission Type")
plt.xlabel("Number of Patients")
plt.ylabel("Admission Type")

plt.show()

# %% [raw]
# Insight
#
# Identify which admission type is most common.

# %% [markdown]
# ### Insurance Type

# %%
plt.figure(figsize=(8,5))

sns.countplot(
    y='Insurance_Type',
    hue='Insurance_Type',
    data=df,
    order=df['Insurance_Type'].value_counts().index,
    palette='Set3',
    legend=False
)

plt.title("Insurance Type")
plt.xlabel("Number of Patients")
plt.ylabel("Insurance Type")

plt.show()

# %% [markdown]
# ### Readmission by Gender

# %%
plt.figure(figsize=(7,5))

sns.countplot(
    x='Gender',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='Set2'
)

plt.title("Readmission by Gender")

plt.show()

# %% [raw]
# Insight
#
# Comment on whether one gender appears to have a higher proportion of readmissions.

# %% [markdown]
# ### Age vs Readmission

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Readmitted_Within_30_Days',
    y='Age',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='Set2',
    legend=False
)

plt.title("Age vs Readmission")
plt.xlabel("Readmitted Within 30 Days")
plt.ylabel("Age")

plt.show()

# %% [raw]
# nsight
#
# Compare the age distributions between readmitted and non-readmitted patients.

# %% [markdown]
# ### Length of Stay vs Readmission

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Readmitted_Within_30_Days',
    y='Length_of_Stay',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='Set1',
    legend=False
)

plt.title("Length of Stay vs Readmission")

plt.show()

# %% [raw]
# Insight
#
# Assess whether patients with longer hospital stays tend to be readmitted more frequently

# %% [markdown]
# ### Chronic Disease Count vs Readmission

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Readmitted_Within_30_Days',
    y='Chronic_Disease_Count',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='coolwarm',
    legend=False
)

plt.title("Chronic Disease Count vs Readmission")

plt.show()

# %% [markdown]
# ### Medication Adherence vs Readmission

# %%
plt.figure(figsize=(8,5))

sns.boxplot(
    x='Readmitted_Within_30_Days',
    y='Medication_Adherence_Score',
    hue='Readmitted_Within_30_Days',
    data=df,
    palette='Blues',
    legend=False
)

plt.title("Medication Adherence vs Readmission")

plt.show()

# %% [raw]
# Insight
#
# Compare medication adherence scores between readmitted and non-readmitted patients.

# %% [raw]
# Data Preprocessing
# Separate Features and Target
#
# Our target variable is:
# Readmitted_Within_30_Days
#
# Create the feature matrix (X) and target vector (y):

# %%
# Features
X = df.drop('Readmitted_Within_30_Days', axis=1)

# Target
y = df['Readmitted_Within_30_Days']

# %% [markdown]
# ### Identify Numerical and Categorical Features

# %%
# Numerical columns
numerical_features = X.select_dtypes(include=['int64', 'float64']).columns

# Categorical columns
categorical_features = X.select_dtypes(include=['object']).columns

print("Numerical Features:")
print(numerical_features)

print("\nCategorical Features:")
print(categorical_features)
# Out:
# Numerical Features:
# Index(['Age', 'Socioeconomic_Risk_Score', 'Previous_Admissions_6M',
#        'Previous_Readmissions_1Y', 'Time_Since_Last_Discharge',
#        'Length_of_Stay', 'Comorbidity_Index', 'Chronic_Disease_Count',
#        'ICU_Stay_Flag', 'Severity_Score', 'HbA1c_Level', 'Creatinine_Level',
#        'Hemoglobin_Level', 'Average_Systolic_BP', 'Number_of_Medications',
#        'Medication_Change_Count', 'High_Risk_Medication_Flag',
#        'Followup_Appointment_Scheduled', 'Medication_Adherence_Score'],
#       dtype='object')
#
# Categorical Features:
# Index(['Gender', 'Insurance_Type', 'Admission_Type', 'Primary_Diagnosis_Group',
#        'Discharge_Disposition'],
#       dtype='object')

# %% [markdown]
# ### Encode Categorical Variabl

# %% [raw]
# Since machine learning models cannot work directly with text values,
# we'll convert categorical variables into numbers using One-Hot Encoding.

# %%
# One-Hot Encode categorical variables
X = pd.get_dummies(
    X,
    columns=categorical_features,
    drop_first=True
)

# Display the new shape
print("Shape after encoding:", X.shape)
# Out:
# Shape after encoding: (18000, 30)

# %% [markdown]
# ### convert the boolean columns to integers:

# %%
X = X.astype(int)

# %%
bool_cols = X.select_dtypes(include='bool').columns
X[bool_cols] = X[bool_cols].astype(int)

# %% [raw]
# Why use drop_first=True?
#
# It removes one category from each encoded feature
# to avoid multicollinearity
# (also called the "dummy variable trap") in many statistical models.

# %% [raw]
# Verify the Data

# %%
X.head()
# Out:
#    Age  Socioeconomic_Risk_Score  Previous_Admissions_6M  \
# 0   71                         9                       2
# 1   34                         8                       4
# 2   80                         2                       1
# 3   40                         7                       2
# 4   43                         5                       2
#
#    Previous_Readmissions_1Y  Time_Since_Last_Discharge  Length_of_Stay  \
# 0                         0                         96              15
# 1                         0                         58              12
# 2                         3                         25              11
# 3                         0                         42               2
# 4                         1                        176               3
#
#    Comorbidity_Index  Chronic_Disease_Count  ICU_Stay_Flag  Severity_Score  \
# 0                  4                      3              1               8
# ...

# %% [markdown]
# ### Split the Datas

# %% [raw]
# We'll use an 80/20 split while preserving the proportion
# of readmitted and non-readmitted patients.

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20,
    random_state=42,
    stratify=y
)

# %% [raw]
# Check the Shapes

# %%
print("Training Features:", X_train.shape)
print("Testing Features :", X_test.shape)

print("Training Labels :", y_train.shape)
print("Testing Labels  :", y_test.shape)
# Out:
# Training Features: (14400, 30)
# Testing Features : (3600, 30)
# Training Labels : (14400,)
# Testing Labels  : (3600,)

# %% [raw]
# (The exact number of columns depends on how many
# categories were created during one-hot encoding.)

# %% [markdown]
# ### Feature Scaling

# %% [raw]
# We'll use StandardScaler because it works well with models
# like Logistic Regression and Support Vector Machines.

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train)

X_test_scaled = scaler.transform(X_test)

# %% [raw]
# Verify Scaling

# %%
print(type(X_train_scaled))
print(X_train_scaled.shape)
# Out:
# <class 'numpy.ndarray'>
# (14400, 30)

# %% [markdown]
# ### Machine Learning

# %% [raw]
# Import the Required Libraries

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import (
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    roc_auc_score,
    confusion_matrix,
    classification_report
)

# %% [markdown]
# ### Then add another column to your results table:

# %% [markdown]
# ### Logistic Regression

# %%
lr_model = LogisticRegression(
    class_weight='balanced',
    random_state=42,
    max_iter=1000
)

# %% [markdown]
# ### Evaluate Logistic Regression

# %%
# Train the model
lr_model.fit(X_train_scaled, y_train)

# Predictions
lr_pred = lr_model.predict(X_test_scaled)
lr_prob = lr_model.predict_proba(X_test_scaled)[:, 1]

# Metrics
print("Accuracy :", accuracy_score(y_test, lr_pred))
print("Precision:", precision_score(y_test, lr_pred))
print("Recall   :", recall_score(y_test, lr_pred))
print("F1 Score :", f1_score(y_test, lr_pred))
print("ROC-AUC  :", roc_auc_score(y_test, lr_prob))

# Classification Report
print(classification_report(y_test, lr_pred))
# Out:
# Accuracy : 0.5458333333333333
# Precision: 0.7765900587920898
# Recall   : 0.5441947565543072
# F1 Score : 0.6399471482052411
# ROC-AUC  : 0.5669944827030727
#               precision    recall  f1-score   support
#
#            0       0.30      0.55      0.39       930
#            1       0.78      0.54      0.64      2670
#
#     accuracy                           0.55      3600
#    macro avg       0.54      0.55      0.51      3600
# weighted avg       0.65      0.55      0.57      3600

# %%
print(df.dtypes)
# Out:
# Age                                 int64
# Gender                             object
# Insurance_Type                     object
# Socioeconomic_Risk_Score            int64
# Previous_Admissions_6M              int64
# Previous_Readmissions_1Y            int64
# Time_Since_Last_Discharge           int64
# Length_of_Stay                      int64
# Admission_Type                     object
# Primary_Diagnosis_Group            object
# Comorbidity_Index                   int64
# Chronic_Disease_Count               int64
# ICU_Stay_Flag                       int64
# Severity_Score                      int64
# HbA1c_Level                       float64
# Creatinine_Level                  float64
# Hemoglobin_Level                  float64
# Average_Systolic_BP                 int64
# Number_of_Medications               int64
# Medication_Change_Count             int64
# High_Risk_Medication_Flag           int64
# Followup_Appointment_Scheduled      int64
# ...

# %% [markdown]
# ### Classification Report

# %%
print(classification_report(y_test, lr_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.30      0.55      0.39       930
#            1       0.78      0.54      0.64      2670
#
#     accuracy                           0.55      3600
#    macro avg       0.54      0.55      0.51      3600
# weighted avg       0.65      0.55      0.57      3600

# %%
y.value_counts()
# Out:
# Readmitted_Within_30_Days
# 1    13349
# 0     4651
# Name: count, dtype: int64

# %%
y.value_counts(normalize=True) * 100
# Out:
# Readmitted_Within_30_Days
# 1    74.161111
# 0    25.838889
# Name: proportion, dtype: float64

# %% [markdown]
# ### Confusion Matrix

# %%
import seaborn as sns
import matplotlib.pyplot as plt

cm = confusion_matrix(y_test, lr_pred)

plt.figure(figsize=(6,5))

sns.heatmap(
    cm,
    annot=True,
    fmt='d',
    cmap='Blues'
)

plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.title("Logistic Regression Confusion Matrix")

plt.show()

# %% [markdown]
# ### Decision Tree

# %% [raw]
# Decision Trees do not require scaling.

# %%
dt_model = DecisionTreeClassifier(
    random_state=42
)

dt_model.fit(X_train, y_train)

dt_pred = dt_model.predict(X_test)

dt_prob = dt_model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Evaluate Decision Tree

# %%
print("Accuracy :", accuracy_score(y_test, dt_pred))
print("Precision:", precision_score(y_test, dt_pred))
print("Recall   :", recall_score(y_test, dt_pred))
print("F1 Score :", f1_score(y_test, dt_pred))
print("ROC-AUC  :", roc_auc_score(y_test, dt_prob))
# Out:
# Accuracy : 0.6052777777777778
# Precision: 0.7406551059730251
# Recall   : 0.7198501872659177
# F1 Score : 0.7301044634377968
# ROC-AUC  : 0.49809713664371147

# %% [markdown]
# ### Random Forest

# %%
rf_model = RandomForestClassifier(
    n_estimators=200,
    random_state=42
)

rf_model.fit(X_train, y_train)

rf_pred = rf_model.predict(X_test)

rf_prob = rf_model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Evaluate Random Forest

# %%
print("Accuracy :", accuracy_score(y_test, rf_pred))
print("Precision:", precision_score(y_test, rf_pred))
print("Recall   :", recall_score(y_test, rf_pred))
print("F1 Score :", f1_score(y_test, rf_pred))
print("ROC-AUC  :", roc_auc_score(y_test, rf_prob))
# Out:
# Accuracy : 0.7413888888888889
# Precision: 0.7415948874687414
# Recall   : 0.999625468164794
# F1 Score : 0.8514914659435316
# ROC-AUC  : 0.5477379082598366

# %% [markdown]
# ### Gradient Boosting

# %%
gb_model = GradientBoostingClassifier(
    random_state=42
)

gb_model.fit(X_train, y_train)

gb_pred = gb_model.predict(X_test)

gb_prob = gb_model.predict_proba(X_test)[:,1]

# %% [markdown]
# ### Evaluate Gradient Boosting

# %%
print("Accuracy :", accuracy_score(y_test, gb_pred))
print("Precision:", precision_score(y_test, gb_pred))
print("Recall   :", recall_score(y_test, gb_pred))
print("F1 Score :", f1_score(y_test, gb_pred))
print("ROC-AUC  :", roc_auc_score(y_test, gb_prob))
# Out:
# Accuracy : 0.7419444444444444
# Precision: 0.7418727424284524
# Recall   : 1.0
# F1 Score : 0.8518104960918806
# ROC-AUC  : 0.5666280053159358

# %% [markdown]
# ### Compare All Models

# %% [raw]
# Create a comparison table to identify the best-performing model.

# %%
from sklearn.metrics import balanced_accuracy_score

results = pd.DataFrame({
    "Model": [
        "Logistic Regression",
        "Decision Tree",
        "Random Forest",
        "Gradient Boosting"
    ],
    "Accuracy": [
        accuracy_score(y_test, lr_pred),
        accuracy_score(y_test, dt_pred),
        accuracy_score(y_test, rf_pred),
        accuracy_score(y_test, gb_pred)
    ],
    "Balanced Accuracy": [
        balanced_accuracy_score(y_test, lr_pred),
        balanced_accuracy_score(y_test, dt_pred),
        balanced_accuracy_score(y_test, rf_pred),
        balanced_accuracy_score(y_test, gb_pred)
    ],
    "Precision": [
        precision_score(y_test, lr_pred),
        precision_score(y_test, dt_pred),
        precision_score(y_test, rf_pred),
        precision_score(y_test, gb_pred)
    ],
    "Recall": [
        recall_score(y_test, lr_pred),
        recall_score(y_test, dt_pred),
        recall_score(y_test, rf_pred),
        recall_score(y_test, gb_pred)
    ],
    "F1 Score": [
        f1_score(y_test, lr_pred),
        f1_score(y_test, dt_pred),
        f1_score(y_test, rf_pred),
        f1_score(y_test, gb_pred)
    ],
    "ROC-AUC": [
        roc_auc_score(y_test, lr_prob),
        roc_auc_score(y_test, dt_prob),
        roc_auc_score(y_test, rf_prob),
        roc_auc_score(y_test, gb_prob)
    ]
})

results.sort_values(by="ROC-AUC", ascending=False)
# Out:
#                  Model  Accuracy  Balanced Accuracy  Precision    Recall  \
# 0  Logistic Regression  0.545833           0.547366   0.776590  0.544195
# 3    Gradient Boosting  0.741944           0.500538   0.741873  1.000000
# 2        Random Forest  0.741389           0.499813   0.741595  0.999625
# 1        Decision Tree  0.605278           0.498097   0.740655  0.719850
#
#    F1 Score   ROC-AUC
# 0  0.639947  0.566994
# 3  0.851810  0.566628
# 2  0.851491  0.547738
# 1  0.730104  0.498097

# %%
y.value_counts()
# Out:
# Readmitted_Within_30_Days
# 1    13349
# 0     4651
# Name: count, dtype: int64

# %%
from sklearn.metrics import confusion_matrix

print(confusion_matrix(y_test, rf_pred))
# Out:
# [[   0  930]
#  [   1 2669]]

# %%
print(confusion_matrix(y_test, gb_pred))
# Out:
# [[   1  929]
#  [   0 2670]]

# %% [markdown]
# ### Feature_importance

# %%
import pandas as pd

feature_importance = pd.DataFrame({
    "Feature": X.columns,
    "Importance": rf_model.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by="Importance",
    ascending=False
)

feature_importance.head(15)
# Out:
#                       Feature  Importance
# 4   Time_Since_Last_Discharge    0.092218
# 0                         Age    0.087059
# 13        Average_Systolic_BP    0.086988
# 5              Length_of_Stay    0.069015
# 14      Number_of_Medications    0.061622
# 12           Hemoglobin_Level    0.055827
# 1    Socioeconomic_Risk_Score    0.053564
# 9              Severity_Score    0.051001
# 10                HbA1c_Level    0.049136
# 6           Comorbidity_Index    0.041870
# 15    Medication_Change_Count    0.040094
# 7       Chronic_Disease_Count    0.036168
# 2      Previous_Admissions_6M    0.035906
# 3    Previous_Readmissions_1Y    0.031364
# 11           Creatinine_Level    0.019156

# %% [markdown]
# ### Then visualize it

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10,8))

sns.barplot(
    data=feature_importance.head(15),
    x="Importance",
    y="Feature"
)

plt.title("Top 15 Most Important Features")

plt.show()

# %% [markdown]
# ### Feature Importance Analysis:

# %% [raw]
# Random Forest identified Time Since
# Last Discharge, Age, Average Systolic Blood Pressure, Length of Stay,
# and Number of Medications as the most influential features.
# These variables are clinically meaningful and align with
# factors commonly associated with hospital readmission risk.
# However, despite these plausible predictors, overall model discrimination
# remained modest, suggesting that the synthetic dataset contains
# limited predictive signal for the target variable.

# %% [markdown]
# ### Cross-Validation

# %%
from sklearn.model_selection import cross_val_score

cv_scores = cross_val_score(
    rf_model,
    X,
    y,
    cv=5,
    scoring="roc_auc"
)

print("Cross-Validation ROC-AUC Scores:", cv_scores)
print("Average ROC-AUC:", cv_scores.mean())
print("Standard Deviation:", cv_scores.std())
# Out:
# Cross-Validation ROC-AUC Scores: [0.54613447 0.53695602 0.54864685 0.56010128 0.5413725 ]
# Average ROC-AUC: 0.5466422257036422
# Standard Deviation: 0.007836008663051331

# %% [markdown]
# ### Save the trained Random Forest model using joblib.

# %%
import joblib

# %%
import joblib

joblib.dump(rf_model, "models/random_forest_readmission_model.pkl")
# Out:
# ['models/random_forest_readmission_model.pkl']

# %% [markdown]
# ### Load the model

# %%
loaded_model = joblib.load("models/random_forest_readmission_model.pkl")

# %% [markdown]
# ### Test Loading the Model

# %%
print(type(loaded_model))
# Out:
# <class 'sklearn.ensemble._forest.RandomForestClassifier'>

# %% [markdown]
# ### Test a Prediction

# %%
sample_prediction = loaded_model.predict(X_test.iloc[:5])

print(sample_prediction)
# Out:
# [1 1 1 1 1]

# %%
import os

model_path = os.path.abspath("models/random_forest_readmission_model.pkl")

print(model_path)
# Out:
# C:\Users\USER\Documents\DATA SCIENCE PROJECTS\models\random_forest_readmission_model.pkl

# %% [markdown]
# ### Use stronger compression:

# %%
joblib.dump(
    rf_model,
    "models/random_forest_readmission_model.pkl",
    compress=9
)
# Out:
# ['models/random_forest_readmission_model.pkl']

# %% [markdown]
# ### Then check its size again:

# %%
import os

size = os.path.getsize("models/random_forest_readmission_model.pkl") / (1024 * 1024)
print(f"{size:.2f} MB")
# Out:
# 12.58 MB

# %% [markdown]
# ### Save the Scaler

# %%
joblib.dump(scaler, "models/scaler.pkl")
# Out:
# ['models/scaler.pkl']

# %% [raw]
# Let's locate your actual project

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\USER\Documents\DATA SCIENCE PROJECTS

# %%
This will tell us the folder where your notebook is currently working.

# %%
import os

print(os.path.abspath("models"))
# Out:
# C:\Users\USER\Documents\DATA SCIENCE PROJECTS\models

# %% [raw]
# I also want you to check the model size

# %%
import os

for file in os.listdir("models"):
    path = os.path.join("models", file)
    size = os.path.getsize(path) / (1024 * 1024)
    print(f"{file}: {size:.2f} MB")
# Out:
# feature_names.pkl: 0.00 MB
# quality_of_life_model.pkl: 0.89 MB
# random_forest_readmission_model.pkl: 12.58 MB
# scaler.pkl: 0.00 MB
